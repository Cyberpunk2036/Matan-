# %%
import math

eps = 0.0000001

a2 = 1
n = 2
diff = abs(a2-a1)


while diff > eps:
    a1 = a2
    a2 = n/(pow(factorial(n), 1/n))
    diff = abs(a2-a1)
    n += 1
    print(diff)

print(diff < eps, a2)
# Out:
# 0.414213562373095
# 0.236750062074218
# 0.156240382772376
# 0.112055740967198
# 0.0848853814115200
# 0.0668514992387168
# 0.0542039306049085
# 0.0449559774594914
# 0.0379686763044846
# 0.0325480344968123
# 0.0282501431164146
# 0.0247795643578930
# 0.0219330637246054
# 0.0195668649670782
# 0.0175767817970587
# 0.0158857256826446
# 0.0144356060384423
# 0.0131819354850862
# 0.0120901507787812
# 0.0111330505313179
# 0.0102889768885310
# 0.00954050317203681
# 0.00887347210684730
# 0.00827628111553302
# 0.00773934442764856
# 0.00725468352272873
# 0.00681561193030245
# 0.00641649023699520
# 0.00605253391004545
# 0.00571966126218060
# 0.00541437221558683
# 0.00513365090712536
# 0.00487488690212423
# 0.00463581104554356
# 0.00441444291090232
# 0.00420904750161677
# 0.00401809938149844
# 0.00384025280681266
# 0.00367431673469820
# 0.00351923381525365
# 0.00337406265499807
# 0.00323796277991173
# 0.00311018183670431
# 0.00299004465798669
# 0.00287694388630788
# 0.00277033190716169
# ...

# %%
from sympy import *
init_printing()

n = Symbol('n')

a = n/(pow(factorial(n), 1/n))
a
# Out:
#     -1
#     ───
#      n
# n⋅n!

# %%
abs(float(limit(a, n, oo)) - a2)
# Out:
# 0.00129340473482609

# %% [markdown]
# Хммм... Разница между табличным значением и полученным слишком велика!
